# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/boostcourse-ds-511/blob/master/pima-classification-baseline-02.ipynb)
#
# * [부스트코스] 프로젝트로 배우는 데이터사이언스 > 3. 탐색한 데이터로 모델성능 개선 의 파일입니다.
#
# https://www.boostcourse.org/ds214/joinLectures/40944
#
# ## 데이터셋 출처
# * [Pima Indians Diabetes Database | Kaggle](https://www.kaggle.com/uciml/pima-indians-diabetes-database)
# * https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html
#
#
# ### 데이터 구성
#
# * Pregnancies : 임신 횟수
# * Glucose : 2시간 동안의 경구 포도당 내성 검사에서 혈장 포도당 농도
# * BloodPressure : 이완기 혈압 (mm Hg)
# * SkinThickness : 삼두근 피부 주름 두께 (mm), 체지방을 추정하는데 사용되는 값
# * Insulin : 2시간 혈청 인슐린 (mu U / ml)
# * BMI : 체질량 지수 (체중kg / 키(m)^2)
# * DiabetesPedigreeFunction : 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 768개 중에 268개의 결과 클래스 변수(0 또는 1)는 1이고 나머지는 0입니다.
#
#
# ## 필요한 라이브러리 로드

# %%
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy
# 시각화를 위한 seaborn, matplotlib.pyplot 을 로드합니다.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 데이터셋 로드

# %%
df = pd.read_csv("http://bit.ly/data-diabetes-csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 다양한 옵션을 지정하여 모델의 성능을 개선해볼 수도 있지만 feature engineering을 해보겠습니다.
#
#
# 수치의 범위가 넓으면 수치형 변수의 조건이 너무 세분화되어 tree가 깊어집니다.
#
# <img src = "https://cphinf.pstatic.net/mooc/20200513_104/1589306199035cM2rR_PNG/mceclip0.png">
#
# 샘플의 수가 적으면 오퍼피팅(과적합)이 발생할 가능성이 높습니다.
#
# 오버피팅이란 모의고사에 너무 익숙해져서 실전시험에서 좋은 결과를 얻지 못하는 현상입니다.
#
#
# 그러므로 수치형 데이터를 범주화하여 성능을 높여보겠습니다.

# %% [markdown]
# ## Feature Engineering
# ## 수치형 변수를 범주형 변수로 만들기1 (임신횟수 기준)

# %%
df["Pregnancies_high"] = df["Pregnancies"] > 6 # 6번을 기준으로 pregnancies_high 정의
df[["Pregnancies", "Pregnancies_high"]].head() # pandas에서 여러개의 column을 보고싶을 때에는 리스트 형태로 묶어준다.
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %% [markdown]
# ## 학습, 예측 데이터셋 나누기

# %%
# 8:2의 비율로 구하기 위해 전체 데이터 행에서 80% 위치에 해당되는 값을 구해서 split_count라는 변수에 담습니다.
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
# train, test로 슬라이싱을 통해 데이터를 나눕니다.
train = df[:split_count].copy()
train.shape
# Out:
# (614, 10)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 10)

# %% [markdown]
# ## 학습, 예측에 사용할 컬럼

# %%
#feature_names 라는 변수에 학습과 예측에 사용할 컬럼명을 가져옵니다.
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Pregnancies_high']

# %% [markdown]
# ## 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼의 이름을 담습니다.
label_name = "Outcome"
label_name
# Out:
# 'Outcome'

# %% [markdown]
# ## 학습, 예측 데이터 셋 만들기

# %%
# 학습 세트 만들기 예) 시험의 기출문제
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Pregnancies_high
# 0                     0.627   50             False
# 1                     0.351   31             False
# 2                     0.672   32              True
# 3                     0.167   21             False
# 4                     2.288   33             False

# %%
# 정답 값을 만들어 줍니다. 예) 기출문제의 정답
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (614,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험문제
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 8)
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 614      138             74             26      144  36.1
# 615      106             72              0        0  25.8
# 616      117             96              0        0  28.7
# 617       68             62             13       15  20.1
# 618      112             82             24        0  28.2
#
#      DiabetesPedigreeFunction  Age  Pregnancies_high
# 614                     0.557   50              True
# 615                     0.207   27             False
# 616                     0.157   30             False
# 617                     0.257   23             False
# 618                     1.282   50              True

# %%
# 예측의 정답값 예) 실전 시험 문제의 정답
y_test = test[label_name]
print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %% [markdown]
# ## 머신러닝 알고리즘 가져오기

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 학습 (훈련)
# - 시험을 볼 때 기출문제(X_train)와 정답(y_train)을 보고 공부하는 과정과 유사합니다.

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 예측
# - 실전 시험문제(X_test)라고 보면 됩니다. 우리가 정답을 직접 예측합니다.

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)

# %% [markdown]
# ## 트리 알고리즘 분석하기
# * 의사결정나무를 시각화 합니다.

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model,
                 feature_names=feature_names,
                 max_depth=4,
                 filled=True,
                 fontsize=10) #여전히 Glucose가 중요한 역할을 하고 있다.

# %%
# 피처의 중요도를 추출하기

model.feature_importances_
# Out:
# array([0.34937919, 0.13903603, 0.06498303, 0.05846867, 0.15489999,
#        0.12511217, 0.10812092, 0.        ])

# %%
# 피처의 중요도 시각화 하기

sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %% [markdown]
# 여전히 Glucose가 중요한 역할을 하고 있고 Pregnancies_high는 중요한 역할을 하고 있지 않다.

# %% [markdown]
# ## 정확도(Accuracy) 측정하기

# %%
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# 39

# %% [markdown]
# 전체적으로 틀린 개수가 39개로 줄어들어서 점수가 74점으로 좋아졌습니다.

# %%
(len(y_test) - diff_count) / len(y_test) * 100
# Out:
# 74.67532467532467

# %%
# 위에서 처럼 직접 구할 수도 있지만 미리 구현된 알고리즘을 가져와 사용합니다.

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict) * 100
# Out:
# 74.67532467532467

# %%
# model 의 score 로 점수를 계산합니다.
model.score(X_test, y_test) * 100
# Out:
# 74.67532467532467

# %% [markdown]
# ## 수치형 변수를 범주형 변수로 만들기 (나이기준)

# %%
# One-Hot-Encoding (하나의 컬럼을 구간별로 나눠 각각의 컬럼으로 나눔)
# 수치 => 범주 => 수치 (범주형 값에 해당되느냐? 안되느냐? 구분할 수 없기 때문에 구간별로 나눔)
df["Age_low"] = df["Age"] < 25
df["Age_middle"] = (df["Age"] >= 25) & (df["Age"] <= 60) #조건 소괄호, pandasd에서는 and 쓰면 오류 '&'써야함
df["Age_high"] = df["Age"] > 60
df[["Age", "Age_low", "Age_middle", "Age_high"]].head()
# Out:
#    Age  Age_low  Age_middle  Age_high
# 0   50    False        True     False
# 1   31    False        True     False
# 2   32    False        True     False
# 3   21     True       False     False
# 4   33    False        True     False

# %%
sns.countplot(data=df, x="Age_low", hue="Outcome")
# Out:
# <Axes: xlabel='Age_low', ylabel='count'>

# %%
sns.countplot(data=df, x="Age_middle", hue="Outcome")
# Out:
# <Axes: xlabel='Age_middle', ylabel='count'>

# %%
sns.countplot(data=df, x="Age_high", hue="Outcome")
# Out:
# <Axes: xlabel='Age_high', ylabel='count'>

# %% [markdown]
# ## 학습, 예측 데이터 셋 나누기

# %%
# 8:2의 비율로 구하기 위해 전체 데이터 행에서 80% 위치에 해당되는 값을 구해서 split_count라는 변수에 담습니다.
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
# train, test로 슬라이싱을 통해 데이터를 나눕니다.
train = df[:split_count].copy()
train.shape
# Out:
# (614, 13)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 13)

# %% [markdown]
# ## 학습, 예측에 사용할 컬럼

# %%
#feature_names 라는 변수에 학습과 예측에 사용할 컬럼명을 가져옵니다.
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Pregnancies_high',
#  'Age_low',
#  'Age_middle',
#  'Age_high']

# %% [markdown]
# ## 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼의 이름을 담습니다.
label_name = "Outcome"
label_name
# Out:
# 'Outcome'

# %% [markdown]
# ## 학습, 예측 데이터 셋 만들기

# %%
# 학습 세트 만들기 예) 시험의 기출문제
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 11)
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Pregnancies_high  Age_low  Age_middle  \
# 0                     0.627   50             False    False        True
# 1                     0.351   31             False    False        True
# 2                     0.672   32              True    False        True
# 3                     0.167   21             False     True       False
# 4                     2.288   33             False    False        True
#
#    Age_high
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# 정답 값을 만들어 줍니다. 예) 기출문제의 정답
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (614,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험문제
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 11)
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 614      138             74             26      144  36.1
# 615      106             72              0        0  25.8
# 616      117             96              0        0  28.7
# 617       68             62             13       15  20.1
# 618      112             82             24        0  28.2
#
#      DiabetesPedigreeFunction  Age  Pregnancies_high  Age_low  Age_middle  \
# 614                     0.557   50              True    False        True
# 615                     0.207   27             False    False        True
# 616                     0.157   30             False    False        True
# 617                     0.257   23             False     True       False
# 618                     1.282   50              True    False        True
#
#      Age_high
# 614     False
# 615     False
# 616     False
# 617     False
# 618     False

# %%
# 예측의 정답값 예) 실전 시험 문제의 정답
y_test = test[label_name]
print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %% [markdown]
# ## 머신러닝 알고리즘 가져오기

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 학습 (훈련)
# - 시험을 볼 때 기출문제(X_train)와 정답(y_train)을 보고 공부하는 과정과 유사합니다.

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 예측
# - 실전 시험문제(X_test)라고 보면 됩니다. 우리가 정답을 직접 예측합니다.

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)

# %% [markdown]
# ## 트리 알고리즘 분석하기
# * 의사결정나무를 시각화 합니다.

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model,
                 feature_names=feature_names,
                 max_depth=4,
                 filled=True,
                 fontsize=10) #여전히 Glucose가 중요한 역할을 하고 있다.

# %%
# 피처의 중요도를 추출하기

model.feature_importances_
# Out:
# array([0.3494391 , 0.1516612 , 0.05192374, 0.06151   , 0.15165656,
#        0.10472174, 0.12189907, 0.        , 0.        , 0.0071886 ,
#        0.        ])

# %%
# 피처의 중요도 시각화 하기

sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %% [markdown]
# ## 정확도(Accuracy) 측정하기

# %%
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# 38

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict) * 100
# Out:
# 75.32467532467533

# %%
# model 의 score 로 점수를 계산합니다.
model.score(X_test, y_test) * 100
# Out:
# 75.32467532467533

# %% [markdown]
# 머신러닝에 추가적인 기능을 적용하게 되면 오히려 성능이 떨어질 수도 있다는 것을 알아볼 수 있었음

# %% [markdown]
# ### 결측치 다루기

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# Pregnancies_high              0
# Age_low                       0
# Age_middle                    0
# Age_high                      0
# Insulin_nan                 374
# dtype: int64

# %%
df.describe() #요약
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
#
#        Insulin_nan
# count   394.000000
# mean    155.548223
# std     118.775855
# min      14.000000
# 25%      76.250000
# 50%     125.000000
# 75%     190.000000
# max     846.000000

# %% [markdown]
# df.isnull() 했을 때에는 결측치가 없어보이지만 df.describe()를 해주었을 때 결측치를 발견
#
# BloodPressure이나 SkinThickness의 최솟값이 0이 될 수가 없다

# %%
df["Insulin_nan"] = df["Insulin"].replace(0, np.nan) #Insulin이 0인 값을 nan값으로 바꿔줌
df[["Insulin", "Insulin_nan"]].head()
# Out:
#    Insulin  Insulin_nan
# 0        0          NaN
# 1        0          NaN
# 2        0          NaN
# 3       94         94.0
# 4      168        168.0

# %%
df["Insulin_nan"].isnull().sum() #인슐린의 결측치 374개 있음
# Out:
# 374

# %%
# 결측치 비율 48%
df["Insulin_nan"].isnull().mean()
# Out:
# 0.4869791666666667

# %%
df.groupby(["Outcome"])[["Insulin", "Insulin_nan"]].describe()
# Out:
#         Insulin                                                         \
#           count        mean         std  min  25%   50%     75%    max
# Outcome
# 0         500.0   68.792000   98.865289  0.0  0.0  39.0  105.00  744.0
# 1         268.0  100.335821  138.689125  0.0  0.0   0.0  167.25  846.0
#
#         Insulin_nan
#               count        mean         std   min    25%    50%     75%    max
# Outcome
# 0             264.0  130.287879  102.482237  15.0   66.0  102.5  161.25  744.0
# 1             130.0  206.846154  132.699898  14.0  127.5  169.5  239.25  846.0

# %%
df.groupby(["Outcome"])[["Insulin", "Insulin_nan"]].agg(["mean", "median"]) # Outcome값에 따른 평균값, 중앙값
# Out:
#             Insulin        Insulin_nan
#                mean median        mean median
# Outcome
# 0         68.792000   39.0  130.287879  102.5
# 1        100.335821    0.0  206.846154  169.5

# %%
# 결측치 채우기
df.loc[(df["Outcome"] == 0) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 102.5
df.loc[(df["Outcome"] == 1) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 169.5

# %% [markdown]
# ### 정규분포 만들기
# * 왜도, 첨도

# %%
# sns.distplot(df.loc[df["Insulin"] > 0, "Insulin"])
# seaborn 0.11.0 이상
sns.displot(df.loc[df["Insulin"] > 0, "Insulin"], kde=True)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Insulin_log = np.log(df.loc[df["Insulin"] > 0, "Insulin"] + 1)
# sns.distplot(Insulin_log)
# seaborn 0.11.0 이상
sns.displot(Insulin_log, kde=True)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df, x="Insulin_nan", kde=True)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df["Insulin_log"] = np.log(df["Insulin_nan"] + 1)
sns.displot(df, x="Insulin_log", kde=True)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 파생변수 만들기
# * EDA에서 해본 상관분석을 바탕으로 파생변수를 생성합니다.

# %%
sns.lmplot(data=df, x="Insulin_nan", y="Glucose", hue="Outcome")
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df["low_glu_insulin"] = (df["Glucose"] < 100) & (df["Insulin_nan"] <= 102.5)
df["low_glu_insulin"].head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: low_glu_insulin, dtype: bool

# %%
pd.crosstab(df["Outcome"], df["low_glu_insulin"])
# Out:
# low_glu_insulin  False  True
# Outcome
# 0                  332    168
# 1                  263      5

# %% [markdown]
# ### 이상치(outlier) 다루기
# * https://ko.wikipedia.org/wiki/%EC%83%81%EC%9E%90_%EC%88%98%EC%97%BC_%EA%B7%B8%EB%A6%BC

# %%
plt.figure(figsize=(15, 2))
sns.boxplot(data=df, x="Insulin_nan")
# Out:
# <Axes: xlabel='Insulin_nan'>

# %%
df["Insulin_nan"].describe()
# Out:
# count    768.000000
# mean     141.753906
# std       89.100847
# min       14.000000
# 25%      102.500000
# 50%      102.500000
# 75%      169.500000
# max      846.000000
# Name: Insulin_nan, dtype: float64

# %%
IQR3 = df["Insulin_nan"].quantile(0.75)
IQR1 = df["Insulin_nan"].quantile(0.25)
IQR = IQR3 - IQR1
IQR
# Out:
# 67.0

# %%
OUT = IQR3 + (IQR * 1.5)
OUT
# Out:
# 270.0

# %%
df[df["Insulin_nan"] > OUT].shape
# Out:
# (51, 16)

# %%
df[df["Insulin_nan"] > 600].shape
# Out:
# (3, 16)

# %% [markdown]
# ### Scaling
# * https://scikit-learn.org/stable/modules/preprocessing.html#standardization-or-mean-removal-and-variance-scaling
# * https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# * https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
# * https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df[["Glucose", "DiabetesPedigreeFunction"]])
scale = scaler.transform(df[["Glucose", "DiabetesPedigreeFunction"]])
scale
# Out:
# array([[ 0.84832379,  0.46849198],
#        [-1.12339636, -0.36506078],
#        [ 1.94372388,  0.60439732],
#        ...,
#        [ 0.00330087, -0.68519336],
#        [ 0.1597866 , -0.37110101],
#        [-0.8730192 , -0.47378505]])

# %%
# df[["Glucose", "DiabetesPedigreeFunction"]] = scale
# df[["Glucose", "DiabetesPedigreeFunction"]].head()

# %%
h = df[["Glucose", "DiabetesPedigreeFunction"]].hist(figsize=(15, 3))

# %% [markdown]
# ## CSV 파일로 저장하기

# %%
df.to_csv("./data/diabetes_feature.csv", index=False)

# %%
pd.read_csv("./data/diabetes_feature.csv").head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Pregnancies_high  Age_low  \
# 0                     0.627   50        1             False    False
# 1                     0.351   31        0             False    False
# 2                     0.672   32        1              True    False
# 3                     0.167   21        0             False     True
# 4                     2.288   33        1             False    False
#
#    Age_middle  Age_high  Insulin_nan  Insulin_log  low_glu_insulin
# 0        True     False        169.5     5.138735            False
# 1        True     False        102.5     4.639572             True
# 2        True     False        169.5     5.138735            False
# 3       False     False         94.0     4.553877             True
# 4        True     False        168.0     5.129899            False

# %% [markdown]
# ## 학습, 예측 데이터셋 나누기

# %%
# 8:2 의 비율로 구하기 위해 전체 데이터의 행에서 80% 위치에 해당되는 값을 구해서 split_count 라는 변수에 담습니다.
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
# train, test로 슬라이싱을 통해 데이터를 나눕니다.
train = df[:split_count].copy()
train.shape
# Out:
# (614, 16)

# %%
train[train["Insulin_nan"] < 600].shape
# Out:
# (610, 16)

# %%
train = train[train["Insulin_nan"] < 600]
train.shape
# Out:
# (610, 16)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 16)

# %% [markdown]
# ## 학습, 예측에 사용할 컬럼

# %%
# feature_names 라는 변수에 학습과 예측에 사용할 컬럼명을 가져옵니다.
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names.remove("Age_low")
feature_names.remove("Age_middle")
feature_names.remove("Age_high")
feature_names.remove("Insulin")
feature_names.remove("Insulin_log")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Pregnancies_high',
#  'Insulin_nan',
#  'low_glu_insulin']

# %% [markdown]
# ## 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼의 이름을 담습니다.

label_name = "Outcome"
label_name
# Out:
# 'Outcome'

# %% [markdown]
# ## 학습, 예측 데이터셋 만들기

# %%
# 학습 세트 만들기 예) 시험의 기출문제

X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (610, 9)
#    Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  Age  \
# 0      148             72             35  33.6                     0.627   50
# 1       85             66             29  26.6                     0.351   31
# 2      183             64              0  23.3                     0.672   32
# 3       89             66             23  28.1                     0.167   21
# 4      137             40             35  43.1                     2.288   33
#
#    Pregnancies_high  Insulin_nan  low_glu_insulin
# 0             False        169.5            False
# 1             False        102.5             True
# 2              True        169.5            False
# 3             False         94.0             True
# 4             False        168.0            False

# %%
# 정답 값을 만들어 줍니다. 예) 기출문제의 정답
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (610,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험 문제

X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 9)
#      Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  \
# 614      138             74             26  36.1                     0.557
# 615      106             72              0  25.8                     0.207
# 616      117             96              0  28.7                     0.157
# 617       68             62             13  20.1                     0.257
# 618      112             82             24  28.2                     1.282
#
#      Age  Pregnancies_high  Insulin_nan  low_glu_insulin
# 614   50              True        144.0            False
# 615   27             False        102.5            False
# 616   30             False        102.5            False
# 617   23             False         15.0             True
# 618   50              True        169.5            False

# %%
# 예측의 정답값 예) 실전 시험 문제의 정답
y_test = test[label_name]

print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %% [markdown]
# ## 머신러닝 알고리즘 가져오기

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %% [markdown]
# ## 학습(훈련)
# * 시험을 볼 때 기출문제(X_train)와 정답(y_train)을 보고 공부하는 과정과 유사합니다.

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %% [markdown]
# ## 예측
# * 실전 시험문제(X_test)라고 보면 됩니다. 우리가 정답을 직접 예측합니다.

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 0, 0, 1])

# %% [markdown]
# ## 트리 알고리즘 분석하기
# * 의사결정나무를 시각화 합니다.

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model,
                 feature_names=feature_names,
                 max_depth=4,
                 filled=True,
                 fontsize=10)

# %%
# graphviz 를 통해 시각화 합니다.
# graphviz 는 별도의 설치가 필요합니다.
# graphviz 와 파이썬에서 graphviz 를 사용할 수 있게 해주는 도구 2가지를 설치해 주셔야 합니다.
# import graphviz
# from sklearn.tree import export_graphviz

# dot_tree = export_graphviz(model,
#                            feature_names = feature_names,
#                            filled=True)
# graphviz.Source(dot_tree)

# %%
# 피처의 중요도를 추출하기

model.feature_importances_
# Out:
# array([0.10720708, 0.03829317, 0.02739544, 0.08008031, 0.02662991,
#        0.08272508, 0.        , 0.63283861, 0.0048304 ])

# %%
# 피처의 중요도 시각화 하기

sns.barplot(x=model.feature_importances_, y=feature_names)

# %% [markdown]
# ## 정확도(Accuracy) 측정하기

# %%
# 실제값 - 예측값을 빼주면 같은 값은 0으로 나오게 됩니다.
# 여기에서 절대값을 씌운 값이 1인 값이 다르게 예측한 값이 됩니다.
# 44 => 39 => 49(나이25세 기준) => 55(나이30세 기준)
# => 23(인슐린 결측치를 평균으로 대체) => 16(인슐린 결측치를 중앙값으로 대체)
# => 15(인슐린&글루코스 파생수변수 추가)
# => 15(인슐린 수치 600이상 이상치제거 )
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# 15

# %%
# 예측의 정확도를 구합니다. 100점 만점 중에 몇 점을 맞았는지 구한다고 보면 됩니다.
# 71 => => 85(인슐린 결측치를 평균으로 대체) => 89(인슐린의 결측치를 중앙값으로 대체)
# => 90(인슐린&글루코스 상관계수로 파생변수를 생성)
(len(y_test) - diff_count) / len(y_test) * 100
# Out:
# 90.25974025974025

# %%
# 위에서 처럼 직접 구할 수도 있지만 미리 구현된 알고리즘을 가져와 사용합니다.

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict) * 100
# Out:
# 90.25974025974025

# %%
# model 의 score 로 점수를 계산합니다.
model.score(X_test, y_test) * 100
# Out:
# 90.25974025974025
